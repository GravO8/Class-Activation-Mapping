# %% [markdown]
# # CAM - class activation map

# %% [markdown]
# # Define models

# %%
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from google.colab import files

def plot_and_save(model_train, model_name):
  fig, (loss_ax, acc_ax) = plt.subplots(1, 2, figsize=(20,7))
  loss_ax.set_title('Loss')
  loss_ax.plot(model_train.history['loss'], '-r', label='Train')
  loss_ax.plot(model_train.history['val_loss'], '-g', label='Validation')
  acc_ax.set_title('Accuracy')
  acc_ax.plot(model_train.history['accuracy'], '-r', label='Train')
  acc_ax.plot(model_train.history['val_accuracy'], '-g', label='Validation')
  plt.legend(loc = 4)
  figname = "{}.png".format(model_name)
  plt.savefig(figname)
  files.download(figname)


def test_train(model, model_name: str, model_description: str):
  model_weights = "{}.h5".format(model_name)
  earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 10, verbose = 1)
  checkpoint = tf.keras.callbacks.ModelCheckpoint(model_weights, 
                                                  monitor         = 'val_accuracy', 
                                                  verbose         = 1, 
                                                  save_best_only  = True)
  start = time.time()
  model_train = model.fit(mnist_train_x, 
                          mnist_train_y, 
                          validation_split  = 0.2, 
                          callbacks         = [earlystop, checkpoint], 
                          epochs            = 10000, 
                          batch_size        = 256)
  elapsed = time.time() - start
  model.load_weights(model_weights)
  plot_and_save(model_train, model_name)
  print(model_name)
  _, train_acc = model.evaluate(mnist_train_x, mnist_train_y)
  print('Train accuracy: {}'.format(train_acc))
  _, test_acc = model.evaluate(mnist_test_x, mnist_test_y)
  print('Test accuracy: {}'.format(test_acc))
  files.download(model_weights)
  with open("results.csv", "a") as f:
    f.write("{};{};{};{};{}\n".format(model_name, model_description, elapsed, train_acc, test_acc))
  confusion_train, confusion_test = "{}-confusion_train.csv".format(model_name), "{}-confusion_test.csv".format(model_name)
  np.savetxt(confusion_train, confusion_matrix(mnist_train_y, np.argmax(model.predict(mnist_train_x),axis=1)), delimiter=",")
  np.savetxt(confusion_test, confusion_matrix(mnist_test_y, np.argmax(model.predict(mnist_test_x),axis=1)), delimiter=",")
  files.download(confusion_train)
  files.download(confusion_test)
  print("----------------------------------------------------------------------")

def model_summary(model):
  string_list = []
  model.summary(print_fn=lambda x: string_list.append(x))
  short_model_summary = "\n".join(string_list)
  return short_model_summary

# %%
import tensorflow_datasets as tfds

mnist_data, mnist_info = tfds.load('mnist', with_info=True)
# Out:
# Downloading and preparing dataset mnist/3.0.1 (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to /root/tensorflow_datasets/mnist/3.0.1...
# WARNING:absl:Dataset mnist is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead pass
# `try_gcs=True` to `tfds.load` or set `data_dir=gs://tfds-data/datasets`.
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %%
import numpy as np

mnist_train_x = np.asarray([instance['image']/255 for instance in tfds.as_numpy(mnist_data['train'])])
mnist_train_y = np.asarray([instance['label'] for instance in tfds.as_numpy(mnist_data['train'])])

mnist_test_x = np.asarray([instance['image']/255 for instance in tfds.as_numpy(mnist_data['test'])])
mnist_test_y = np.asarray([instance['label'] for instance in tfds.as_numpy(mnist_data['test'])])

# %%
image_shape = mnist_train_x[0].shape
image_shape
# Out:
# (28, 28, 1)

# %%
import tensorflow as tf

model_name_c2 = "model_c2"
model_description_c2 =\
'''
SAPO
'''
model_c2 = tf.keras.Sequential(name = model_name_c2)
model_c2.add(tf.keras.layers.Input(image_shape))
model_c2.add(tf.keras.layers.Conv2D(filters = 16, 
                                    kernel_size = (3,3),
                                    activation="relu", 
                                    padding="same", 
                                    name="convolution_1"))
model_c2.add(tf.keras.layers.Conv2D(filters = 16, 
                                    kernel_size = (3,3),
                                    activation="relu", 
                                    padding="same", 
                                    name="convolution_2"))
model_c2.add(tf.keras.layers.Conv2D(filters = 32, 
                                    kernel_size = (3,3),
                                    activation="relu", 
                                    padding="same", 
                                    name="convolution_3"))
model_c2.add(tf.keras.layers.Conv2D(filters = 256, 
                                    kernel_size = (3,3),
                                    activation="relu", 
                                    padding="same", 
                                    name="convolution_4"))
model_c2.add(tf.keras.layers.GlobalAveragePooling2D(name = "GAP"))
model_c2.add(tf.keras.layers.Dense(10, 
                                   activation='softmax', 
                                   name='output',
                                   use_bias = False))
model_c2.compile(loss='sparse_categorical_crossentropy', 
                 optimizer='Adam', 
                 metrics=['accuracy'])
model_c2.summary()
model_description_c2 = model_summary(model_c2) + model_description_c2
model_description_c2 = model_description_c2.replace("\n","\\n")
# Out:
# Model: "model_c2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# convolution_1 (Conv2D)       (None, 28, 28, 16)        160
# _________________________________________________________________
# convolution_2 (Conv2D)       (None, 28, 28, 16)        2320
# _________________________________________________________________
# convolution_3 (Conv2D)       (None, 28, 28, 32)        4640
# _________________________________________________________________
# convolution_4 (Conv2D)       (None, 28, 28, 256)       73984
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                2560
# =================================================================
# Total params: 83,664
# Trainable params: 83,664
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define functions

# %% [markdown]
# ## Test and train

# %%
with open("results.csv", "w+") as f:
  f.write("model name;model description;training time;train accuracy;test accuracy\n")
test_train(model_c2, model_name_c2, model_description_c2)
files.download("results.csv")
# Out:
# Epoch 1/10000
# 188/188 [==============================] - 448s 2s/step - loss: 1.7468 - accuracy: 0.3492 - val_loss: 1.3548 - val_accuracy: 0.5152
#
# Epoch 00001: val_accuracy improved from -inf to 0.51517, saving model to model_c2.h5
# Epoch 2/10000
# 188/188 [==============================] - 450s 2s/step - loss: 1.1242 - accuracy: 0.6369 - val_loss: 0.9341 - val_accuracy: 0.7237
#
# Epoch 00002: val_accuracy improved from 0.51517 to 0.72367, saving model to model_c2.h5
# Epoch 3/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.7685 - accuracy: 0.7657 - val_loss: 0.6592 - val_accuracy: 0.8069
#
# Epoch 00003: val_accuracy improved from 0.72367 to 0.80692, saving model to model_c2.h5
# Epoch 4/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.5844 - accuracy: 0.8252 - val_loss: 0.5165 - val_accuracy: 0.8444
#
# Epoch 00004: val_accuracy improved from 0.80692 to 0.84442, saving model to model_c2.h5
# Epoch 5/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.4881 - accuracy: 0.8537 - val_loss: 0.4420 - val_accuracy: 0.8709
#
# Epoch 00005: val_accuracy improved from 0.84442 to 0.87092, saving model to model_c2.h5
# Epoch 6/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.4404 - accuracy: 0.8688 - val_loss: 0.3940 - val_accuracy: 0.8861
#
# Epoch 00006: val_accuracy improved from 0.87092 to 0.88608, saving model to model_c2.h5
# Epoch 7/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.3724 - accuracy: 0.8893 - val_loss: 0.3210 - val_accuracy: 0.9066
#
# Epoch 00007: val_accuracy improved from 0.88608 to 0.90658, saving model to model_c2.h5
# Epoch 8/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.3391 - accuracy: 0.9000 - val_loss: 0.3274 - val_accuracy: 0.9010
#
# Epoch 00008: val_accuracy did not improve from 0.90658
# Epoch 9/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.3100 - accuracy: 0.9099 - val_loss: 0.2735 - val_accuracy: 0.9210
#
# Epoch 00009: val_accuracy improved from 0.90658 to 0.92100, saving model to model_c2.h5
# Epoch 10/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.2932 - accuracy: 0.9138 - val_loss: 0.2534 - val_accuracy: 0.9256
#
# Epoch 00010: val_accuracy improved from 0.92100 to 0.92558, saving model to model_c2.h5
# Epoch 11/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.2693 - accuracy: 0.9215 - val_loss: 0.2528 - val_accuracy: 0.9269
#
# Epoch 00011: val_accuracy improved from 0.92558 to 0.92692, saving model to model_c2.h5
# Epoch 12/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.2482 - accuracy: 0.9272 - val_loss: 0.2502 - val_accuracy: 0.9282
#
# Epoch 00012: val_accuracy improved from 0.92692 to 0.92817, saving model to model_c2.h5
# Epoch 13/10000
# 188/188 [==============================] - 448s 2s/step - loss: 0.2376 - accuracy: 0.9297 - val_loss: 0.2642 - val_accuracy: 0.9220
#
# Epoch 00013: val_accuracy did not improve from 0.92817
# Epoch 14/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.2303 - accuracy: 0.9329 - val_loss: 0.2160 - val_accuracy: 0.9373
#
# Epoch 00014: val_accuracy improved from 0.92817 to 0.93733, saving model to model_c2.h5
# Epoch 15/10000
# 188/188 [==============================] - 452s 2s/step - loss: 0.2146 - accuracy: 0.9382 - val_loss: 0.1956 - val_accuracy: 0.9421
#
# Epoch 00015: val_accuracy improved from 0.93733 to 0.94208, saving model to model_c2.h5
# Epoch 16/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.2039 - accuracy: 0.9413 - val_loss: 0.2436 - val_accuracy: 0.9245
#
# Epoch 00016: val_accuracy did not improve from 0.94208
# Epoch 17/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.1919 - accuracy: 0.9442 - val_loss: 0.1708 - val_accuracy: 0.9507
#
# Epoch 00017: val_accuracy improved from 0.94208 to 0.95067, saving model to model_c2.h5
# Epoch 18/10000
# 188/188 [==============================] - 452s 2s/step - loss: 0.1838 - accuracy: 0.9465 - val_loss: 0.1738 - val_accuracy: 0.9485
#
# Epoch 00018: val_accuracy did not improve from 0.95067
# Epoch 19/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.1835 - accuracy: 0.9469 - val_loss: 0.1890 - val_accuracy: 0.9418
#
# Epoch 00019: val_accuracy did not improve from 0.95067
# Epoch 20/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.1663 - accuracy: 0.9517 - val_loss: 0.1726 - val_accuracy: 0.9503
#
# Epoch 00020: val_accuracy did not improve from 0.95067
# Epoch 21/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.1667 - accuracy: 0.9516 - val_loss: 0.1671 - val_accuracy: 0.9504
#
# Epoch 00021: val_accuracy did not improve from 0.95067
# Epoch 22/10000
# 188/188 [==============================] - 453s 2s/step - loss: 0.1602 - accuracy: 0.9534 - val_loss: 0.1676 - val_accuracy: 0.9504
#
# Epoch 00022: val_accuracy did not improve from 0.95067
# Epoch 23/10000
# 188/188 [==============================] - 453s 2s/step - loss: 0.1583 - accuracy: 0.9541 - val_loss: 0.1438 - val_accuracy: 0.9597
#
# Epoch 00023: val_accuracy improved from 0.95067 to 0.95967, saving model to model_c2.h5
# Epoch 24/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.1443 - accuracy: 0.9573 - val_loss: 0.1272 - val_accuracy: 0.9625
#
# Epoch 00024: val_accuracy improved from 0.95967 to 0.96250, saving model to model_c2.h5
# Epoch 25/10000
# 188/188 [==============================] - 453s 2s/step - loss: 0.1508 - accuracy: 0.9561 - val_loss: 0.1277 - val_accuracy: 0.9642
#
# Epoch 00025: val_accuracy improved from 0.96250 to 0.96417, saving model to model_c2.h5
# Epoch 26/10000
# 188/188 [==============================] - 453s 2s/step - loss: 0.1362 - accuracy: 0.9592 - val_loss: 0.1350 - val_accuracy: 0.9603
#
# Epoch 00026: val_accuracy did not improve from 0.96417
# Epoch 27/10000
# 188/188 [==============================] - 455s 2s/step - loss: 0.1352 - accuracy: 0.9603 - val_loss: 0.1468 - val_accuracy: 0.9575
#
# Epoch 00027: val_accuracy did not improve from 0.96417
# Epoch 28/10000
# 188/188 [==============================] - 454s 2s/step - loss: 0.1374 - accuracy: 0.9597 - val_loss: 0.1882 - val_accuracy: 0.9456
#
# Epoch 00028: val_accuracy did not improve from 0.96417
# Epoch 29/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.1314 - accuracy: 0.9607 - val_loss: 0.1282 - val_accuracy: 0.9628
#
# Epoch 00029: val_accuracy did not improve from 0.96417
# Epoch 30/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.1264 - accuracy: 0.9635 - val_loss: 0.1333 - val_accuracy: 0.9612
#
# Epoch 00030: val_accuracy did not improve from 0.96417
# Epoch 31/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1253 - accuracy: 0.9630 - val_loss: 0.1204 - val_accuracy: 0.9638
#
# Epoch 00031: val_accuracy did not improve from 0.96417
# Epoch 32/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1195 - accuracy: 0.9642 - val_loss: 0.1195 - val_accuracy: 0.9636
#
# Epoch 00032: val_accuracy did not improve from 0.96417
# Epoch 33/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.1193 - accuracy: 0.9649 - val_loss: 0.1048 - val_accuracy: 0.9682
#
# Epoch 00033: val_accuracy improved from 0.96417 to 0.96825, saving model to model_c2.h5
# Epoch 34/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1204 - accuracy: 0.9644 - val_loss: 0.1156 - val_accuracy: 0.9638
#
# Epoch 00034: val_accuracy did not improve from 0.96825
# Epoch 35/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1118 - accuracy: 0.9668 - val_loss: 0.1086 - val_accuracy: 0.9680
#
# Epoch 00035: val_accuracy did not improve from 0.96825
# Epoch 36/10000
# 188/188 [==============================] - 448s 2s/step - loss: 0.1074 - accuracy: 0.9682 - val_loss: 0.0999 - val_accuracy: 0.9694
#
# Epoch 00036: val_accuracy improved from 0.96825 to 0.96942, saving model to model_c2.h5
# Epoch 37/10000
# 188/188 [==============================] - 446s 2s/step - loss: 0.1134 - accuracy: 0.9664 - val_loss: 0.1300 - val_accuracy: 0.9637
#
# Epoch 00037: val_accuracy did not improve from 0.96942
# Epoch 38/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1089 - accuracy: 0.9672 - val_loss: 0.0970 - val_accuracy: 0.9715
#
# Epoch 00038: val_accuracy improved from 0.96942 to 0.97150, saving model to model_c2.h5
# Epoch 39/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.1042 - accuracy: 0.9690 - val_loss: 0.1067 - val_accuracy: 0.9673
#
# Epoch 00039: val_accuracy did not improve from 0.97150
# Epoch 40/10000
# 188/188 [==============================] - 459s 2s/step - loss: 0.1038 - accuracy: 0.9690 - val_loss: 0.1320 - val_accuracy: 0.9596
#
# Epoch 00040: val_accuracy did not improve from 0.97150
# Epoch 41/10000
# 188/188 [==============================] - 459s 2s/step - loss: 0.1021 - accuracy: 0.9705 - val_loss: 0.0831 - val_accuracy: 0.9766
#
# Epoch 00041: val_accuracy improved from 0.97150 to 0.97658, saving model to model_c2.h5
# Epoch 42/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.0979 - accuracy: 0.9710 - val_loss: 0.1120 - val_accuracy: 0.9676
#
# Epoch 00042: val_accuracy did not improve from 0.97658
# Epoch 43/10000
# 188/188 [==============================] - 447s 2s/step - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.0852 - val_accuracy: 0.9757
#
# Epoch 00043: val_accuracy did not improve from 0.97658
# Epoch 44/10000
# 188/188 [==============================] - 446s 2s/step - loss: 0.0984 - accuracy: 0.9710 - val_loss: 0.1041 - val_accuracy: 0.9683
#
# Epoch 00044: val_accuracy did not improve from 0.97658
# Epoch 45/10000
# 188/188 [==============================] - 446s 2s/step - loss: 0.0951 - accuracy: 0.9707 - val_loss: 0.0968 - val_accuracy: 0.9704
#
# Epoch 00045: val_accuracy did not improve from 0.97658
# Epoch 46/10000
# 188/188 [==============================] - 446s 2s/step - loss: 0.0935 - accuracy: 0.9719 - val_loss: 0.1049 - val_accuracy: 0.9702
#
# Epoch 00046: val_accuracy did not improve from 0.97658
# Epoch 47/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.0895 - accuracy: 0.9733 - val_loss: 0.0821 - val_accuracy: 0.9756
#
# Epoch 00047: val_accuracy did not improve from 0.97658
# Epoch 48/10000
# 188/188 [==============================] - 447s 2s/step - loss: 0.0875 - accuracy: 0.9743 - val_loss: 0.0917 - val_accuracy: 0.9715
#
# Epoch 00048: val_accuracy did not improve from 0.97658
# Epoch 49/10000
# 188/188 [==============================] - 449s 2s/step - loss: 0.0879 - accuracy: 0.9740 - val_loss: 0.0787 - val_accuracy: 0.9767
#
# Epoch 00049: val_accuracy improved from 0.97658 to 0.97667, saving model to model_c2.h5
# Epoch 50/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.0869 - accuracy: 0.9725 - val_loss: 0.1111 - val_accuracy: 0.9666
#
# Epoch 00050: val_accuracy did not improve from 0.97667
# Epoch 51/10000
# 188/188 [==============================] - 451s 2s/step - loss: 0.0824 - accuracy: 0.9754 - val_loss: 0.0809 - val_accuracy: 0.9761
#
# Epoch 00051: val_accuracy did not improve from 0.97667
# Epoch 52/10000
# 188/188 [==============================] - 450s 2s/step - loss: 0.0863 - accuracy: 0.9744 - val_loss: 0.0851 - val_accuracy: 0.9756
#
# Epoch 00052: val_accuracy did not improve from 0.97667
# Epoch 53/10000
# 166/188 [=========================>....] - ETA: 49s - loss: 0.0794 - accuracy: 0.9761
